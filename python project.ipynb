# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("/Users/michaelmekonnen/Downloads/archive/usercardata.csv")
df.head()                      #shows the first five rows
# Out:
#    Sales_ID     name  year  selling_price  km_driven   Region  \
# 0         1   Maruti  2014         450000     145500     East
# 1         2    Skoda  2014         370000     120000     East
# 2         3    Honda  2006         158000     140000  Central
# 3         4  Hyundai  2010         225000     127000  Central
# 4         5   Maruti  2007         130000     120000     East
#
#       State or Province           City    fuel seller_type transmission  \
# 0  District of Columbia     Washington  Diesel  Individual       Manual
# 1              New York  New York City  Diesel  Individual       Manual
# 2              Illinois        Chicago  Petrol  Individual       Manual
# 3              Illinois        Chicago  Diesel  Individual       Manual
# 4              New York  New York City  Petrol  Individual       Manual
#
#           owner  mileage  engine  max_power                    torque  seats  \
# 0   First_Owner    23.40    1248      74.00            190Nm@ 2000rpm      5
# ...

# %%
df.tail()         # shows the last five rows
# Out:
#       Sales_ID     name  year  selling_price  km_driven   Region  \
# 7901      8124  Hyundai  2013         320000     110000  Central
# 7902      8125  Hyundai  2007         135000     119000  Central
# 7903      8126   Maruti  2009         382000     120000  Central
# 7904      8127     Tata  2013         290000      25000     East
# 7905      8128     Tata  2013         290000      25000     East
#
#      State or Province         City    fuel seller_type transmission  \
# 7901             Texas        Plano  Petrol  Individual       Manual
# 7902             Texas  Port Arthur  Diesel  Individual       Manual
# 7903             Texas  Port Arthur  Diesel  Individual       Manual
# 7904     Massachusetts    Lunenburg  Diesel  Individual       Manual
# 7905             Maine      Augusta  Diesel  Individual       Manual
#
#                    owner  mileage  engine  max_power  \
# 7901         First_Owner    18.50    1197      82.85
# ...

# %%
df.columns
# Out:
# Index(['Sales_ID', 'name', 'year', 'selling_price', 'km_driven', 'Region',
#        'State or Province', 'City', 'fuel', 'seller_type', 'transmission',
#        'owner', 'mileage', 'engine', 'max_power', 'torque', 'seats', 'sold'],
#       dtype='object')

# %%
df.drop(["Region", "mileage", "engine", "max_power","torque",], axis=1, inplace = True) # deleting columns i will not be using

# %%
df.head()
# Out:
#    Sales_ID     name  year  selling_price  km_driven     State or Province  \
# 0         1   Maruti  2014         450000     145500  District of Columbia
# 1         2    Skoda  2014         370000     120000              New York
# 2         3    Honda  2006         158000     140000              Illinois
# 3         4  Hyundai  2010         225000     127000              Illinois
# 4         5   Maruti  2007         130000     120000              New York
#
#             City    fuel seller_type transmission         owner  seats sold
# 0     Washington  Diesel  Individual       Manual   First_Owner      5    Y
# 1  New York City  Diesel  Individual       Manual  Second_Owner      5    Y
# 2        Chicago  Petrol  Individual       Manual   Third_Owner      5    Y
# 3        Chicago  Diesel  Individual       Manual   First_Owner      5    Y
# 4  New York City  Petrol  Individual       Manual   First_Owner      5    Y

# %%
df.sort_values(by = "selling_price" , ascending = False) # sorting by price in descening order
# Out:
#       Sales_ID    name  year  selling_price  km_driven State or Province  \
# 164        171   Volvo  2017       10000000      30000          New York
# 2846      2939     BMW  2020        7200000       5000           Florida
# 4813      4953    Audi  2019        6523000      23600          Missouri
# 4811      4951    Audi  2019        6223000       7800          Missouri
# 1040      1072     BMW  2018        6000000      28156              Iowa
# ...        ...     ...   ...            ...        ...               ...
# 4675      4812  Maruti  2004          33351      90000     Massachusetts
# 1871      1927  Maruti  2004          31504     110000           Florida
# 5796      5966  Maruti  2000          31000      56194          Michigan
# 2081      2146  Maruti  2001          30000      10000             Texas
# 5552      5715  Maruti  1997          29999      80000          Michigan
#
#                     City    fuel seller_type transmission               owner  \
# ...

# %%
# Out:
#    Sales_ID     name  year  selling_price  km_driven     State or Province  \
# 0         1   Maruti  2014         450000     145500  District of Columbia
# 1         2    Skoda  2014         370000     120000              New York
# 2         3    Honda  2006         158000     140000              Illinois
# 3         4  Hyundai  2010         225000     127000              Illinois
# 4         5   Maruti  2007         130000     120000              New York
#
#             City    fuel seller_type transmission         owner  seats sold
# 0     Washington  Diesel  Individual       Manual   First_Owner      5    Y
# 1  New York City  Diesel  Individual       Manual  Second_Owner      5    Y
# 2        Chicago  Petrol  Individual       Manual   Third_Owner      5    Y
# 3        Chicago  Diesel  Individual       Manual   First_Owner      5    Y
# 4  New York City  Petrol  Individual       Manual   First_Owner      5    Y

# %%
df.dropna() #dropping rows with missing values
# Out:
#       Sales_ID     name  year  selling_price  km_driven     State or Province  \
# 0            1   Maruti  2014         450000     145500  District of Columbia
# 1            2    Skoda  2014         370000     120000              New York
# 2            3    Honda  2006         158000     140000              Illinois
# 3            4  Hyundai  2010         225000     127000              Illinois
# 4            5   Maruti  2007         130000     120000              New York
# ...        ...      ...   ...            ...        ...                   ...
# 7901      8124  Hyundai  2013         320000     110000                 Texas
# 7902      8125  Hyundai  2007         135000     119000                 Texas
# 7903      8126   Maruti  2009         382000     120000                 Texas
# 7904      8127     Tata  2013         290000      25000         Massachusetts
# 7905      8128     Tata  2013         290000      25000                 Maine
#
# ...

# %%
 x = df.groupby("seller_type") #grouping by the seller type

# %%
x.mean().round(0)
# Out:
#                   Sales_ID    year  selling_price  km_driven  seats
# seller_type
# Dealer              4071.0  2016.0      1459910.0    44035.0    5.0
# Individual          4085.0  2014.0       507706.0    74400.0    5.0
# Trustmark_Dealer    3664.0  2016.0       801839.0    42259.0    5.0

# %%
y = df.groupby("sold")

# %%
y.mean()
# Out:
#          Sales_ID         year  selling_price    km_driven     seats
# sold
# N     5099.127497  2013.977481  640820.216898  69351.61937  5.410769
# Y     1031.406500  2014.003000  676371.538000  68707.44000  5.433000

# %%
z = df.groupby("City")
z.mean().sort_values(by = "selling_price" , ascending = False)   #the average price by city and order descending
# Out:
#                    Sales_ID         year  selling_price  km_driven  seats
# City
# Cliffside Park  4430.000000  2019.000000      5500000.0     8500.0    5.0
# Groton          6182.000000  2019.000000      5500000.0     8500.0    5.0
# Milton          3410.000000  2019.000000      5150000.0    20000.0    5.0
# Albemarle       1863.333333  2018.666667      4875000.0    20100.0    5.0
# North Haven     6214.000000  2019.000000      3800000.0    20000.0    5.0
# ...                     ...          ...            ...        ...    ...
# Braintree       1475.000000  1994.000000        45000.0    60000.0    4.0
# Chicopee        6321.000000  1998.000000        40000.0    70000.0    4.0
# Waltham         7936.000000  1999.000000        40000.0   100000.0    4.0
# Wilbraham       2257.000000  2007.000000        35000.0    10000.0    4.0
# Gloucester      4812.000000  2004.000000        33351.0    90000.0    5.0
#
# [1310 rows x 5 columns]

# %%
df.plot(kind = "scatter",
        x = "selling_price",
        y = "owner"
       )
# Out:
# <AxesSubplot:xlabel='selling_price', ylabel='owner'>

# %%
df["seller_type"].value_counts().plot(kind = "bar")
# Out:
# <AxesSubplot:>
